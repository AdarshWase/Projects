# %%
% tensorflow_version 1.7
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.7`. This will be interpreted as: `1.x`.
#
#
# TensorFlow 1.x selected.

# %%
 # !pip install q keras==2.0
# Out:
# Requirement already satisfied: q in /usr/local/lib/python3.6/dist-packages (2.6)
# Requirement already satisfied: keras==2.0 in /usr/local/lib/python3.6/dist-packages (2.0.0)
# Requirement already satisfied: tensorflow in /tensorflow-1.15.2/python3.6 (from keras==2.0) (1.15.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras==2.0) (3.13)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from keras==2.0) (1.15.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow->keras==2.0) (1.1.2)
# Requirement already satisfied: gast==0.2.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow->keras==2.0) (0.2.2)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow->keras==2.0) (1.12.1)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow->keras==2.0) (0.35.1)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow->keras==2.0) (0.8.1)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow->keras==2.0) (3.12.4)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow->keras==2.0) (0.10.0)
# Requirement already satisfied: keras-applications>=1.0.8 in /tensorflow-1.15.2/python3.6 (from tensorflow->keras==2.0) (1.0.8)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow->keras==2.0) (1.33.2)
# Requirement already satisfied: tensorflow-estimator==1.15.1 in /tensorflow-1.15.2/python3.6 (from tensorflow->keras==2.0) (1.15.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow->keras==2.0) (3.3.0)
# Requirement already satisfied: tensorboard<1.16.0,>=1.15.0 in /tensorflow-1.15.2/python3.6 (from tensorflow->keras==2.0) (1.15.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow->keras==2.0) (0.2.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow->keras==2.0) (1.18.5)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow->keras==2.0) (1.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow->keras==2.0) (50.3.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow->keras==2.0) (2.10.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow->keras==2.0) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow->keras==2.0) (3.3.3)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow->keras==2.0) (2.0.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow->keras==2.0) (3.4.0)

# %%
import numpy as np
import keras
from keras import layers
from keras import applications
from keras_applications import vgg16
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
from keras.models import Model, load_model
from keras.preprocessing import image
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from keras.applications.imagenet_utils import preprocess_input
import pydot
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from keras.utils import plot_model
from resnets_utils import *
from keras.initializers import glorot_uniform
import scipy.misc
from matplotlib.pyplot import imshow
# %matplotlib inline

import keras.backend as K
K.set_image_data_format('channels_last')
K.set_learning_phase(1)
import h5py
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:120: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
def convert_to_one_hot(Y, C):
    Y = np.eye(C)[Y.reshape(-1)].T
    return Y

# %%
def load_dataset():
    train_dataset = h5py.File('/content/drive/MyDrive/datasets/train_signs.h5', "r")
    train_set_x_orig = np.array(train_dataset["train_set_x"][:]) 
    train_set_y_orig = np.array(train_dataset["train_set_y"][:]) 

    test_dataset = h5py.File('/content/drive/MyDrive/datasets/test_signs.h5', "r")
    test_set_x_orig = np.array(test_dataset["test_set_x"][:])
    test_set_y_orig = np.array(test_dataset["test_set_y"][:])

    classes = np.array(test_dataset["list_classes"][:])
    
    train_set_y_orig = train_set_y_orig.reshape((1, train_set_y_orig.shape[0]))
    test_set_y_orig = test_set_y_orig.reshape((1, test_set_y_orig.shape[0]))
    
    return train_set_x_orig, train_set_y_orig, test_set_x_orig, test_set_y_orig, classes

# %%
X_train_orig, Y_train_orig, X_test_orig, Y_test_orig, classes = load_dataset()

X_train = X_train_orig/255.
X_test = X_test_orig/255.
Y_train = convert_to_one_hot(Y_train_orig, 6).T
Y_test = convert_to_one_hot(Y_test_orig, 6).T

# %%
def identity_block(X, f, filters, stage, block):
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    
    F1, F2, F3 = filters
    X_shortcut = X
    
    X = Conv2D(filters = F1, kernel_size = (1, 1), strides = (1,1), padding = 'valid', name = conv_name_base + '2a', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2a')(X)
    X = Activation('relu')(X)

    X = Conv2D(filters = F2, kernel_size = (f, f), strides = (1, 1), padding = 'same', name = conv_name_base + '2b', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2b')(X)
    X = Activation('relu')(X)

    X = Conv2D(filters = F3, kernel_size = (1, 1), strides = (1, 1), padding = 'valid', name = conv_name_base + '2c', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2c')(X)

    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)
    
    return X

# %%
tf.reset_default_graph()

with tf.Session() as test:
    np.random.seed(1)
    A_prev = tf.placeholder("float", [3, 4, 4, 6])
    X = np.random.randn(3, 4, 4, 6)
    A = identity_block(A_prev, f = 2, filters = [2, 4, 6], stage = 1, block = 'a')
    test.run(tf.global_variables_initializer())
    out = test.run([A], feed_dict={A_prev: X, K.learning_phase(): 0})
    print("out = " + str(out[0][1][1][0]))
# Out:
# out = [0.94822997 0.         1.1610144  2.747859   0.         1.36677   ]

# %%
def convolutional_block(X, f, filters, stage, block, s = 2):

    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    F1, F2, F3 = filters
    X_shortcut = X

    X = Conv2D(F1, (1, 1), strides = (s,s), name = conv_name_base + '2a', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2a')(X)
    X = Activation('relu')(X)
    
    X = Conv2D(F2, (f, f), strides = (1, 1), padding = 'same', name = conv_name_base + '2b', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2b')(X)
    X = Activation('relu')(X)

    X = Conv2D(F3, (1, 1), strides = (1, 1), padding = 'valid', name = conv_name_base + '2c', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2c')(X)

    X_shortcut = Conv2D(F3, (1, 1), strides = (s, s), padding = 'valid', name = conv_name_base + '1', kernel_initializer = glorot_uniform(seed=0))(X_shortcut)
    X_shortcut = BatchNormalization(axis = 3, name = bn_name_base + '1')(X_shortcut)

    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)

    
    return X

# %%
tf.reset_default_graph()

with tf.Session() as test:
    np.random.seed(1)
    A_prev = tf.placeholder("float", [3, 4, 4, 6])
    X = np.random.randn(3, 4, 4, 6)
    A = convolutional_block(A_prev, f = 2, filters = [2, 4, 6], stage = 1, block = 'a')
    test.run(tf.global_variables_initializer())
    out = test.run([A], feed_dict={A_prev: X, K.learning_phase(): 0})
    print("out = " + str(out[0][1][1][0]))
# Out:
# out = [0.09018462 1.2348977  0.46822017 0.03671761 0.         0.65516603]

# %%
def ResNet50(input_shape = (64, 64, 3), classes = 6):
    """
    Implementation of the popular ResNet50 the following architecture:
    CONV2D -> BATCHNORM -> RELU -> MAXPOOL -> CONVBLOCK -> IDBLOCK*2 -> CONVBLOCK -> IDBLOCK*3
    -> CONVBLOCK -> IDBLOCK*5 -> CONVBLOCK -> IDBLOCK*2 -> AVGPOOL -> TOPLAYER

    Arguments:
    input_shape -- shape of the images of the dataset
    classes -- integer, number of classes

    Returns:
    model -- a Model() instance in Keras
    """
    
    # Define the input as a tensor with shape input_shape
    X_input = Input(input_shape)

    
    # Zero-Padding
    X = ZeroPadding2D((3, 3))(X_input)
    
    # Stage 1
    X = Conv2D(64, (7, 7), strides = (2, 2), name = 'conv1', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = 'bn_conv1')(X)
    X = Activation('relu')(X)
    X = MaxPooling2D((3, 3), strides=(2, 2))(X)

    # Stage 2
    X = convolutional_block(X, f = 3, filters = [64, 64, 256], stage = 2, block='a', s = 1)
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='b')
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='c')

    ### START CODE HERE ###

    # Stage 3 (≈4 lines)
    X = convolutional_block(X, f = 3, filters = [128,128,512], stage = 3, block = 'a', s = 2)
    X = identity_block(X, 3, [128,128,512], stage = 3, block = 'b')
    X = identity_block(X, 3, [128,128,512], stage = 3, block = 'c')
    X = identity_block(X, 3, [128,128,512], stage = 3, block = 'd')

    # Stage 4 (≈6 lines)
    X = convolutional_block(X, f = 3, filters = [256, 256, 1024], stage = 4, block = 'a', s = 2)
    X = identity_block(X, 3, [256, 256, 1024], stage = 4, block = 'b')
    X = identity_block(X, 3, [256, 256, 1024], stage = 4, block = 'c')
    X = identity_block(X, 3, [256, 256, 1024], stage = 4, block = 'd')
    X = identity_block(X, 3, [256, 256, 1024], stage = 4, block = 'e')
    X = identity_block(X, 3, [256, 256, 1024], stage = 4, block = 'f')

    
    # Stage 5 (≈3 lines)
    X = convolutional_block(X, f = 3, filters = [512, 512, 2048], stage = 5, block = 'a', s = 2)
    X = identity_block(X, 3, [512, 512, 2048], stage = 5, block = 'b')
    X = identity_block(X, 3, [512, 512, 2048], stage = 5, block = 'c')

    # AVGPOOL (≈1 line). Use "X = AveragePooling2D(...)(X)"
    X = AveragePooling2D(pool_size=(2,2), name = 'avg_pool')(X)
    
    ### END CODE HERE ###

    # output layer
    X = Flatten()(X)
    X = Dense(classes, activation='softmax', name='fc' + str(classes), kernel_initializer = glorot_uniform(seed=0))(X)
    
    
    # Create model
    model = Model(inputs = X_input, outputs = X, name='ResNet50')

    return model

# %%
model = ResNet50(input_shape = (64, 64, 3), classes = 6)

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train, Y_train, epochs = 5, batch_size = 32)
# Out:
# Epoch 1/5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/client/session.py in __init__(self, fetches, contraction_fn)
#     304         self._unique_fetches.append(ops.get_default_graph().as_graph_element(
# --> 305             fetch, allow_tensor=True, allow_operation=True))
#     306       except TypeError as e:
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/framework/ops.py in as_graph_element(self, obj, allow_tensor, allow_operation)
#    3606     with self._lock:
# -> 3607       return self._as_graph_element_locked(obj, allow_tensor, allow_operation)
#    3608
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/framework/ops.py in _as_graph_element_locked(self, obj, allow_tensor, allow_operation)
#    3690       if obj.graph is not self:
# -> 3691         raise ValueError("Operation %s is not an element of this graph." % obj)
#    3692       return obj
#
# ValueError: Operation name: "init_1"
# op: "NoOp"
# input: "^res1a_branch2a/kernel/Assign"
# input: "^res1a_branch2a/bias/Assign"
# input: "^bn1a_branch2a/gamma/Assign"
# input: "^bn1a_branch2a/beta/Assign"
# input: "^bn1a_branch2a/moving_mean/Assign"
# input: "^bn1a_branch2a/moving_variance/Assign"
# input: "^res1a_branch2b/kernel/Assign"
# input: "^res1a_branch2b/bias/Assign"
# input: "^bn1a_branch2b/gamma/Assign"
# input: "^bn1a_branch2b/beta/Assign"
# input: "^bn1a_branch2b/moving_mean/Assign"
# input: "^bn1a_branch2b/moving_variance/Assign"
# input: "^res1a_branch2c/kernel/Assign"
# input: "^res1a_branch2c/bias/Assign"
# input: "^bn1a_branch2c/gamma/Assign"
# input: "^bn1a_branch2c/beta/Assign"
# input: "^bn1a_branch2c/moving_mean/Assign"
# input: "^bn1a_branch2c/moving_variance/Assign"
# input: "^res1a_branch1/kernel/Assign"
# input: "^res1a_branch1/bias/Assign"
# input: "^bn1a_branch1/gamma/Assign"
# input: "^bn1a_branch1/beta/Assign"
# input: "^bn1a_branch1/moving_mean/Assign"
# input: "^bn1a_branch1/moving_variance/Assign"
# input: "^conv1/kernel/Assign"
# input: "^conv1/bias/Assign"
# input: "^bn_conv1/gamma/Assign"
# input: "^bn_conv1/beta/Assign"
# input: "^bn_conv1/moving_mean/Assign"
# input: "^bn_conv1/moving_variance/Assign"
# input: "^res2a_branch2a/kernel/Assign"
# input: "^res2a_branch2a/bias/Assign"
# input: "^bn2a_branch2a/gamma/Assign"
# input: "^bn2a_branch2a/beta/Assign"
# input: "^bn2a_branch2a/moving_mean/Assign"
# input: "^bn2a_branch2a/moving_variance/Assign"
# input: "^res2a_branch2b/kernel/Assign"
# input: "^res2a_branch2b/bias/Assign"
# input: "^bn2a_branch2b/gamma/Assign"
# input: "^bn2a_branch2b/beta/Assign"
# input: "^bn2a_branch2b/moving_mean/Assign"
# input: "^bn2a_branch2b/moving_variance/Assign"
# input: "^res2a_branch2c/kernel/Assign"
# input: "^res2a_branch2c/bias/Assign"
# input: "^bn2a_branch2c/gamma/Assign"
# input: "^bn2a_branch2c/beta/Assign"
# input: "^bn2a_branch2c/moving_mean/Assign"
# input: "^bn2a_branch2c/moving_variance/Assign"
# input: "^res2a_branch1/kernel/Assign"
# input: "^res2a_branch1/bias/Assign"
# input: "^bn2a_branch1/gamma/Assign"
# input: "^bn2a_branch1/beta/Assign"
# input: "^bn2a_branch1/moving_mean/Assign"
# input: "^bn2a_branch1/moving_variance/Assign"
# input: "^res2b_branch2a/kernel/Assign"
# input: "^res2b_branch2a/bias/Assign"
# input: "^bn2b_branch2a/gamma/Assign"
# input: "^bn2b_branch2a/beta/Assign"
# input: "^bn2b_branch2a/moving_mean/Assign"
# input: "^bn2b_branch2a/moving_variance/Assign"
# input: "^res2b_branch2b/kernel/Assign"
# input: "^res2b_branch2b/bias/Assign"
# input: "^bn2b_branch2b/gamma/Assign"
# input: "^bn2b_branch2b/beta/Assign"
# input: "^bn2b_branch2b/moving_mean/Assign"
# input: "^bn2b_branch2b/moving_variance/Assign"
# input: "^res2b_branch2c/kernel/Assign"
# input: "^res2b_branch2c/bias/Assign"
# input: "^bn2b_branch2c/gamma/Assign"
# input: "^bn2b_branch2c/beta/Assign"
# input: "^bn2b_branch2c/moving_mean/Assign"
# input: "^bn2b_branch2c/moving_variance/Assign"
# input: "^res2c_branch2a/kernel/Assign"
# input: "^res2c_branch2a/bias/Assign"
# input: "^bn2c_branch2a/gamma/Assign"
# input: "^bn2c_branch2a/beta/Assign"
# input: "^bn2c_branch2a/moving_mean/Assign"
# input: "^bn2c_branch2a/moving_variance/Assign"
# input: "^res2c_branch2b/kernel/Assign"
# input: "^res2c_branch2b/bias/Assign"
# input: "^bn2c_branch2b/gamma/Assign"
# input: "^bn2c_branch2b/beta/Assign"
# input: "^bn2c_branch2b/moving_mean/Assign"
# input: "^bn2c_branch2b/moving_variance/Assign"
# input: "^res2c_branch2c/kernel/Assign"
# input: "^res2c_branch2c/bias/Assign"
# input: "^bn2c_branch2c/gamma/Assign"
# input: "^bn2c_branch2c/beta/Assign"
# input: "^bn2c_branch2c/moving_mean/Assign"
# input: "^bn2c_branch2c/moving_variance/Assign"
# input: "^res3a_branch2a/kernel/Assign"
# input: "^res3a_branch2a/bias/Assign"
# input: "^bn3a_branch2a/gamma/Assign"
# input: "^bn3a_branch2a/beta/Assign"
# input: "^bn3a_branch2a/moving_mean/Assign"
# input: "^bn3a_branch2a/moving_variance/Assign"
# input: "^res3a_branch2b/kernel/Assign"
# input: "^res3a_branch2b/bias/Assign"
# input: "^bn3a_branch2b/gamma/Assign"
# input: "^bn3a_branch2b/beta/Assign"
# input: "^bn3a_branch2b/moving_mean/Assign"
# input: "^bn3a_branch2b/moving_variance/Assign"
# input: "^res3a_branch2c/kernel/Assign"
# input: "^res3a_branch2c/bias/Assign"
# input: "^bn3a_branch2c/gamma/Assign"
# input: "^bn3a_branch2c/beta/Assign"
# input: "^bn3a_branch2c/moving_mean/Assign"
# input: "^bn3a_branch2c/moving_variance/Assign"
# input: "^res3a_branch1/kernel/Assign"
# input: "^res3a_branch1/bias/Assign"
# input: "^bn3a_branch1/gamma/Assign"
# input: "^bn3a_branch1/beta/Assign"
# input: "^bn3a_branch1/moving_mean/Assign"
# input: "^bn3a_branch1/moving_variance/Assign"
# input: "^res3b_branch2a/kernel/Assign"
# input: "^res3b_branch2a/bias/Assign"
# input: "^bn3b_branch2a/gamma/Assign"
# input: "^bn3b_branch2a/beta/Assign"
# input: "^bn3b_branch2a/moving_mean/Assign"
# input: "^bn3b_branch2a/moving_variance/Assign"
# input: "^res3b_branch2b/kernel/Assign"
# input: "^res3b_branch2b/bias/Assign"
# input: "^bn3b_branch2b/gamma/Assign"
# input: "^bn3b_branch2b/beta/Assign"
# input: "^bn3b_branch2b/moving_mean/Assign"
# input: "^bn3b_branch2b/moving_variance/Assign"
# input: "^res3b_branch2c/kernel/Assign"
# input: "^res3b_branch2c/bias/Assign"
# input: "^bn3b_branch2c/gamma/Assign"
# input: "^bn3b_branch2c/beta/Assign"
# input: "^bn3b_branch2c/moving_mean/Assign"
# input: "^bn3b_branch2c/moving_variance/Assign"
# input: "^res3c_branch2a/kernel/Assign"
# input: "^res3c_branch2a/bias/Assign"
# input: "^bn3c_branch2a/gamma/Assign"
# input: "^bn3c_branch2a/beta/Assign"
# input: "^bn3c_branch2a/moving_mean/Assign"
# input: "^bn3c_branch2a/moving_variance/Assign"
# input: "^res3c_branch2b/kernel/Assign"
# input: "^res3c_branch2b/bias/Assign"
# input: "^bn3c_branch2b/gamma/Assign"
# input: "^bn3c_branch2b/beta/Assign"
# input: "^bn3c_branch2b/moving_mean/Assign"
# input: "^bn3c_branch2b/moving_variance/Assign"
# input: "^res3c_branch2c/kernel/Assign"
# input: "^res3c_branch2c/bias/Assign"
# input: "^bn3c_branch2c/gamma/Assign"
# input: "^bn3c_branch2c/beta/Assign"
# input: "^bn3c_branch2c/moving_mean/Assign"
# input: "^bn3c_branch2c/moving_variance/Assign"
# input: "^res3d_branch2a/kernel/Assign"
# input: "^res3d_branch2a/bias/Assign"
# input: "^bn3d_branch2a/gamma/Assign"
# input: "^bn3d_branch2a/beta/Assign"
# input: "^bn3d_branch2a/moving_mean/Assign"
# input: "^bn3d_branch2a/moving_variance/Assign"
# input: "^res3d_branch2b/kernel/Assign"
# input: "^res3d_branch2b/bias/Assign"
# input: "^bn3d_branch2b/gamma/Assign"
# input: "^bn3d_branch2b/beta/Assign"
# input: "^bn3d_branch2b/moving_mean/Assign"
# input: "^bn3d_branch2b/moving_variance/Assign"
# input: "^res3d_branch2c/kernel/Assign"
# input: "^res3d_branch2c/bias/Assign"
# input: "^bn3d_branch2c/gamma/Assign"
# input: "^bn3d_branch2c/beta/Assign"
# input: "^bn3d_branch2c/moving_mean/Assign"
# input: "^bn3d_branch2c/moving_variance/Assign"
# input: "^res4a_branch2a/kernel/Assign"
# input: "^res4a_branch2a/bias/Assign"
# input: "^bn4a_branch2a/gamma/Assign"
# input: "^bn4a_branch2a/beta/Assign"
# input: "^bn4a_branch2a/moving_mean/Assign"
# input: "^bn4a_branch2a/moving_variance/Assign"
# input: "^res4a_branch2b/kernel/Assign"
# input: "^res4a_branch2b/bias/Assign"
# input: "^bn4a_branch2b/gamma/Assign"
# input: "^bn4a_branch2b/beta/Assign"
# input: "^bn4a_branch2b/moving_mean/Assign"
# input: "^bn4a_branch2b/moving_variance/Assign"
# input: "^res4a_branch2c/kernel/Assign"
# input: "^res4a_branch2c/bias/Assign"
# input: "^bn4a_branch2c/gamma/Assign"
# input: "^bn4a_branch2c/beta/Assign"
# input: "^bn4a_branch2c/moving_mean/Assign"
# input: "^bn4a_branch2c/moving_variance/Assign"
# input: "^res4a_branch1/kernel/Assign"
# input: "^res4a_branch1/bias/Assign"
# input: "^bn4a_branch1/gamma/Assign"
# input: "^bn4a_branch1/beta/Assign"
# input: "^bn4a_branch1/moving_mean/Assign"
# input: "^bn4a_branch1/moving_variance/Assign"
# input: "^res4b_branch2a/kernel/Assign"
# input: "^res4b_branch2a/bias/Assign"
# input: "^bn4b_branch2a/gamma/Assign"
# input: "^bn4b_branch2a/beta/Assign"
# input: "^bn4b_branch2a/moving_mean/Assign"
# input: "^bn4b_branch2a/moving_variance/Assign"
# input: "^res4b_branch2b/kernel/Assign"
# input: "^res4b_branch2b/bias/Assign"
# input: "^bn4b_branch2b/gamma/Assign"
# input: "^bn4b_branch2b/beta/Assign"
# input: "^bn4b_branch2b/moving_mean/Assign"
# input: "^bn4b_branch2b/moving_variance/Assign"
# input: "^res4b_branch2c/kernel/Assign"
# input: "^res4b_branch2c/bias/Assign"
# input: "^bn4b_branch2c/gamma/Assign"
# input: "^bn4b_branch2c/beta/Assign"
# input: "^bn4b_branch2c/moving_mean/Assign"
# input: "^bn4b_branch2c/moving_variance/Assign"
# input: "^res4c_branch2a/kernel/Assign"
# input: "^res4c_branch2a/bias/Assign"
# input: "^bn4c_branch2a/gamma/Assign"
# input: "^bn4c_branch2a/beta/Assign"
# input: "^bn4c_branch2a/moving_mean/Assign"
# input: "^bn4c_branch2a/moving_variance/Assign"
# input: "^res4c_branch2b/kernel/Assign"
# input: "^res4c_branch2b/bias/Assign"
# input: "^bn4c_branch2b/gamma/Assign"
# input: "^bn4c_branch2b/beta/Assign"
# input: "^bn4c_branch2b/moving_mean/Assign"
# input: "^bn4c_branch2b/moving_variance/Assign"
# input: "^res4c_branch2c/kernel/Assign"
# input: "^res4c_branch2c/bias/Assign"
# input: "^bn4c_branch2c/gamma/Assign"
# input: "^bn4c_branch2c/beta/Assign"
# input: "^bn4c_branch2c/moving_mean/Assign"
# input: "^bn4c_branch2c/moving_variance/Assign"
# input: "^res4d_branch2a/kernel/Assign"
# input: "^res4d_branch2a/bias/Assign"
# input: "^bn4d_branch2a/gamma/Assign"
# input: "^bn4d_branch2a/beta/Assign"
# input: "^bn4d_branch2a/moving_mean/Assign"
# input: "^bn4d_branch2a/moving_variance/Assign"
# input: "^res4d_branch2b/kernel/Assign"
# input: "^res4d_branch2b/bias/Assign"
# input: "^bn4d_branch2b/gamma/Assign"
# input: "^bn4d_branch2b/beta/Assign"
# input: "^bn4d_branch2b/moving_mean/Assign"
# input: "^bn4d_branch2b/moving_variance/Assign"
# input: "^res4d_branch2c/kernel/Assign"
# input: "^res4d_branch2c/bias/Assign"
# input: "^bn4d_branch2c/gamma/Assign"
# input: "^bn4d_branch2c/beta/Assign"
# input: "^bn4d_branch2c/moving_mean/Assign"
# input: "^bn4d_branch2c/moving_variance/Assign"
# input: "^res4e_branch2a/kernel/Assign"
# input: "^res4e_branch2a/bias/Assign"
# input: "^bn4e_branch2a/gamma/Assign"
# input: "^bn4e_branch2a/beta/Assign"
# input: "^bn4e_branch2a/moving_mean/Assign"
# input: "^bn4e_branch2a/moving_variance/Assign"
# input: "^res4e_branch2b/kernel/Assign"
# input: "^res4e_branch2b/bias/Assign"
# input: "^bn4e_branch2b/gamma/Assign"
# input: "^bn4e_branch2b/beta/Assign"
# input: "^bn4e_branch2b/moving_mean/Assign"
# input: "^bn4e_branch2b/moving_variance/Assign"
# input: "^res4e_branch2c/kernel/Assign"
# input: "^res4e_branch2c/bias/Assign"
# input: "^bn4e_branch2c/gamma/Assign"
# input: "^bn4e_branch2c/beta/Assign"
# input: "^bn4e_branch2c/moving_mean/Assign"
# input: "^bn4e_branch2c/moving_variance/Assign"
# input: "^res4f_branch2a/kernel/Assign"
# input: "^res4f_branch2a/bias/Assign"
# input: "^bn4f_branch2a/gamma/Assign"
# input: "^bn4f_branch2a/beta/Assign"
# input: "^bn4f_branch2a/moving_mean/Assign"
# input: "^bn4f_branch2a/moving_variance/Assign"
# input: "^res4f_branch2b/kernel/Assign"
# input: "^res4f_branch2b/bias/Assign"
# input: "^bn4f_branch2b/gamma/Assign"
# input: "^bn4f_branch2b/beta/Assign"
# input: "^bn4f_branch2b/moving_mean/Assign"
# input: "^bn4f_branch2b/moving_variance/Assign"
# input: "^res4f_branch2c/kernel/Assign"
# input: "^res4f_branch2c/bias/Assign"
# input: "^bn4f_branch2c/gamma/Assign"
# input: "^bn4f_branch2c/beta/Assign"
# input: "^bn4f_branch2c/moving_mean/Assign"
# input: "^bn4f_branch2c/moving_variance/Assign"
# input: "^res5a_branch2a/kernel/Assign"
# input: "^res5a_branch2a/bias/Assign"
# input: "^bn5a_branch2a/gamma/Assign"
# input: "^bn5a_branch2a/beta/Assign"
# input: "^bn5a_branch2a/moving_mean/Assign"
# input: "^bn5a_branch2a/moving_variance/Assign"
# input: "^res5a_branch2b/kernel/Assign"
# input: "^res5a_branch2b/bias/Assign"
# input: "^bn5a_branch2b/gamma/Assign"
# input: "^bn5a_branch2b/beta/Assign"
# input: "^bn5a_branch2b/moving_mean/Assign"
# input: "^bn5a_branch2b/moving_variance/Assign"
# input: "^res5a_branch2c/kernel/Assign"
# input: "^res5a_branch2c/bias/Assign"
# input: "^bn5a_branch2c/gamma/Assign"
# input: "^bn5a_branch2c/beta/Assign"
# input: "^bn5a_branch2c/moving_mean/Assign"
# input: "^bn5a_branch2c/moving_variance/Assign"
# input: "^res5a_branch1/kernel/Assign"
# input: "^res5a_branch1/bias/Assign"
# input: "^bn5a_branch1/gamma/Assign"
# input: "^bn5a_branch1/beta/Assign"
# input: "^bn5a_branch1/moving_mean/Assign"
# input: "^bn5a_branch1/moving_variance/Assign"
# input: "^res5b_branch2a/kernel/Assign"
# input: "^res5b_branch2a/bias/Assign"
# input: "^bn5b_branch2a/gamma/Assign"
# input: "^bn5b_branch2a/beta/Assign"
# input: "^bn5b_branch2a/moving_mean/Assign"
# input: "^bn5b_branch2a/moving_variance/Assign"
# input: "^res5b_branch2b/kernel/Assign"
# input: "^res5b_branch2b/bias/Assign"
# input: "^bn5b_branch2b/gamma/Assign"
# input: "^bn5b_branch2b/beta/Assign"
# input: "^bn5b_branch2b/moving_mean/Assign"
# input: "^bn5b_branch2b/moving_variance/Assign"
# input: "^res5b_branch2c/kernel/Assign"
# input: "^res5b_branch2c/bias/Assign"
# input: "^bn5b_branch2c/gamma/Assign"
# input: "^bn5b_branch2c/beta/Assign"
# input: "^bn5b_branch2c/moving_mean/Assign"
# input: "^bn5b_branch2c/moving_variance/Assign"
# input: "^res5c_branch2a/kernel/Assign"
# input: "^res5c_branch2a/bias/Assign"
# input: "^bn5c_branch2a/gamma/Assign"
# input: "^bn5c_branch2a/beta/Assign"
# input: "^bn5c_branch2a/moving_mean/Assign"
# input: "^bn5c_branch2a/moving_variance/Assign"
# input: "^res5c_branch2b/kernel/Assign"
# input: "^res5c_branch2b/bias/Assign"
# input: "^bn5c_branch2b/gamma/Assign"
# input: "^bn5c_branch2b/beta/Assign"
# input: "^bn5c_branch2b/moving_mean/Assign"
# input: "^bn5c_branch2b/moving_variance/Assign"
# input: "^res5c_branch2c/kernel/Assign"
# input: "^res5c_branch2c/bias/Assign"
# input: "^bn5c_branch2c/gamma/Assign"
# input: "^bn5c_branch2c/beta/Assign"
# input: "^bn5c_branch2c/moving_mean/Assign"
# input: "^bn5c_branch2c/moving_variance/Assign"
# input: "^fc6/kernel/Assign"
# input: "^fc6/bias/Assign"
# input: "^iterations/Assign"
# input: "^lr/Assign"
# input: "^beta_1/Assign"
# input: "^beta_2/Assign"
# input: "^decay/Assign"
# input: "^Variable/Assign"
# input: "^Variable_1/Assign"
# input: "^Variable_2/Assign"
# input: "^Variable_3/Assign"
# input: "^Variable_4/Assign"
# input: "^Variable_5/Assign"
# input: "^Variable_6/Assign"
# input: "^Variable_7/Assign"
# input: "^Variable_8/Assign"
# input: "^Variable_9/Assign"
# input: "^Variable_10/Assign"
# input: "^Variable_11/Assign"
# input: "^Variable_12/Assign"
# input: "^Variable_13/Assign"
# input: "^Variable_14/Assign"
# input: "^Variable_15/Assign"
# input: "^Variable_16/Assign"
# input: "^Variable_17/Assign"
# input: "^Variable_18/Assign"
# input: "^Variable_19/Assign"
# input: "^Variable_20/Assign"
# input: "^Variable_21/Assign"
# input: "^Variable_22/Assign"
# input: "^Variable_23/Assign"
# input: "^Variable_24/Assign"
# input: "^Variable_25/Assign"
# input: "^Variable_26/Assign"
# input: "^Variable_27/Assign"
# input: "^Variable_28/Assign"
# input: "^Variable_29/Assign"
# input: "^Variable_30/Assign"
# input: "^Variable_31/Assign"
# input: "^Variable_32/Assign"
# input: "^Variable_33/Assign"
# input: "^Variable_34/Assign"
# input: "^Variable_35/Assign"
# input: "^Variable_36/Assign"
# input: "^Variable_37/Assign"
# input: "^Variable_38/Assign"
# input: "^Variable_39/Assign"
# input: "^Variable_40/Assign"
# input: "^Variable_41/Assign"
# input: "^Variable_42/Assign"
# input: "^Variable_43/Assign"
# input: "^Variable_44/Assign"
# input: "^Variable_45/Assign"
# input: "^Variable_46/Assign"
# input: "^Variable_47/Assign"
# input: "^Variable_48/Assign"
# input: "^Variable_49/Assign"
# input: "^Variable_50/Assign"
# input: "^Variable_51/Assign"
# input: "^Variable_52/Assign"
# input: "^Variable_53/Assign"
# input: "^Variable_54/Assign"
# input: "^Variable_55/Assign"
# input: "^Variable_56/Assign"
# input: "^Variable_57/Assign"
# input: "^Variable_58/Assign"
# input: "^Variable_59/Assign"
# input: "^Variable_60/Assign"
# input: "^Variable_61/Assign"
# input: "^Variable_62/Assign"
# input: "^Variable_63/Assign"
# input: "^Variable_64/Assign"
# input: "^Variable_65/Assign"
# input: "^Variable_66/Assign"
# input: "^Variable_67/Assign"
# input: "^Variable_68/Assign"
# input: "^Variable_69/Assign"
# input: "^Variable_70/Assign"
# input: "^Variable_71/Assign"
# input: "^Variable_72/Assign"
# input: "^Variable_73/Assign"
# input: "^Variable_74/Assign"
# input: "^Variable_75/Assign"
# input: "^Variable_76/Assign"
# input: "^Variable_77/Assign"
# input: "^Variable_78/Assign"
# input: "^Variable_79/Assign"
# input: "^Variable_80/Assign"
# input: "^Variable_81/Assign"
# input: "^Variable_82/Assign"
# input: "^Variable_83/Assign"
# input: "^Variable_84/Assign"
# input: "^Variable_85/Assign"
# input: "^Variable_86/Assign"
# input: "^Variable_87/Assign"
# input: "^Variable_88/Assign"
# input: "^Variable_89/Assign"
# input: "^Variable_90/Assign"
# input: "^Variable_91/Assign"
# input: "^Variable_92/Assign"
# input: "^Variable_93/Assign"
# input: "^Variable_94/Assign"
# input: "^Variable_95/Assign"
# input: "^Variable_96/Assign"
# input: "^Variable_97/Assign"
# input: "^Variable_98/Assign"
# input: "^Variable_99/Assign"
# input: "^Variable_100/Assign"
# input: "^Variable_101/Assign"
# input: "^Variable_102/Assign"
# input: "^Variable_103/Assign"
# input: "^Variable_104/Assign"
# input: "^Variable_105/Assign"
# input: "^Variable_106/Assign"
# input: "^Variable_107/Assign"
# input: "^Variable_108/Assign"
# input: "^Variable_109/Assign"
# input: "^Variable_110/Assign"
# input: "^Variable_111/Assign"
# input: "^Variable_112/Assign"
# input: "^Variable_113/Assign"
# input: "^Variable_114/Assign"
# input: "^Variable_115/Assign"
# input: "^Variable_116/Assign"
# input: "^Variable_117/Assign"
# input: "^Variable_118/Assign"
# input: "^Variable_119/Assign"
# input: "^Variable_120/Assign"
# input: "^Variable_121/Assign"
# input: "^Variable_122/Assign"
# input: "^Variable_123/Assign"
# input: "^Variable_124/Assign"
# input: "^Variable_125/Assign"
# input: "^Variable_126/Assign"
# input: "^Variable_127/Assign"
# input: "^Variable_128/Assign"
# input: "^Variable_129/Assign"
# input: "^Variable_130/Assign"
# input: "^Variable_131/Assign"
# input: "^Variable_132/Assign"
# input: "^Variable_133/Assign"
# input: "^Variable_134/Assign"
# input: "^Variable_135/Assign"
# input: "^Variable_136/Assign"
# input: "^Variable_137/Assign"
# input: "^Variable_138/Assign"
# input: "^Variable_139/Assign"
# input: "^Variable_140/Assign"
# input: "^Variable_141/Assign"
# input: "^Variable_142/Assign"
# input: "^Variable_143/Assign"
# input: "^Variable_144/Assign"
# input: "^Variable_145/Assign"
# input: "^Variable_146/Assign"
# input: "^Variable_147/Assign"
# input: "^Variable_148/Assign"
# input: "^Variable_149/Assign"
# input: "^Variable_150/Assign"
# input: "^Variable_151/Assign"
# input: "^Variable_152/Assign"
# input: "^Variable_153/Assign"
# input: "^Variable_154/Assign"
# input: "^Variable_155/Assign"
# input: "^Variable_156/Assign"
# input: "^Variable_157/Assign"
# input: "^Variable_158/Assign"
# input: "^Variable_159/Assign"
# input: "^Variable_160/Assign"
# input: "^Variable_161/Assign"
# input: "^Variable_162/Assign"
# input: "^Variable_163/Assign"
# input: "^Variable_164/Assign"
# input: "^Variable_165/Assign"
# input: "^Variable_166/Assign"
# input: "^Variable_167/Assign"
# input: "^Variable_168/Assign"
# input: "^Variable_169/Assign"
# input: "^Variable_170/Assign"
# input: "^Variable_171/Assign"
# input: "^Variable_172/Assign"
# input: "^Variable_173/Assign"
# input: "^Variable_174/Assign"
# input: "^Variable_175/Assign"
# input: "^Variable_176/Assign"
# input: "^Variable_177/Assign"
# input: "^Variable_178/Assign"
# input: "^Variable_179/Assign"
# input: "^Variable_180/Assign"
# input: "^Variable_181/Assign"
# input: "^Variable_182/Assign"
# input: "^Variable_183/Assign"
# input: "^Variable_184/Assign"
# input: "^Variable_185/Assign"
# input: "^Variable_186/Assign"
# input: "^Variable_187/Assign"
# input: "^Variable_188/Assign"
# input: "^Variable_189/Assign"
# input: "^Variable_190/Assign"
# input: "^Variable_191/Assign"
# input: "^Variable_192/Assign"
# input: "^Variable_193/Assign"
# input: "^Variable_194/Assign"
# input: "^Variable_195/Assign"
# input: "^Variable_196/Assign"
# input: "^Variable_197/Assign"
# input: "^Variable_198/Assign"
# input: "^Variable_199/Assign"
# input: "^Variable_200/Assign"
# input: "^Variable_201/Assign"
# input: "^Variable_202/Assign"
# input: "^Variable_203/Assign"
# input: "^Variable_204/Assign"
# input: "^Variable_205/Assign"
# input: "^Variable_206/Assign"
# input: "^Variable_207/Assign"
# input: "^Variable_208/Assign"
# input: "^Variable_209/Assign"
# input: "^Variable_210/Assign"
# input: "^Variable_211/Assign"
# input: "^Variable_212/Assign"
# input: "^Variable_213/Assign"
# input: "^Variable_214/Assign"
# input: "^Variable_215/Assign"
# input: "^Variable_216/Assign"
# input: "^Variable_217/Assign"
# input: "^Variable_218/Assign"
# input: "^Variable_219/Assign"
# input: "^Variable_220/Assign"
# input: "^Variable_221/Assign"
# input: "^Variable_222/Assign"
# input: "^Variable_223/Assign"
# input: "^Variable_224/Assign"
# input: "^Variable_225/Assign"
# input: "^Variable_226/Assign"
# input: "^Variable_227/Assign"
# input: "^Variable_228/Assign"
# input: "^Variable_229/Assign"
# input: "^Variable_230/Assign"
# input: "^Variable_231/Assign"
# input: "^Variable_232/Assign"
# input: "^Variable_233/Assign"
# input: "^Variable_234/Assign"
# input: "^Variable_235/Assign"
# input: "^Variable_236/Assign"
# input: "^Variable_237/Assign"
# input: "^Variable_238/Assign"
# input: "^Variable_239/Assign"
# input: "^Variable_240/Assign"
# input: "^Variable_241/Assign"
# input: "^Variable_242/Assign"
# input: "^Variable_243/Assign"
# input: "^Variable_244/Assign"
# input: "^Variable_245/Assign"
# input: "^Variable_246/Assign"
# input: "^Variable_247/Assign"
# input: "^Variable_248/Assign"
# input: "^Variable_249/Assign"
# input: "^Variable_250/Assign"
# input: "^Variable_251/Assign"
# input: "^Variable_252/Assign"
# input: "^Variable_253/Assign"
# input: "^Variable_254/Assign"
# input: "^Variable_255/Assign"
# input: "^Variable_256/Assign"
# input: "^Variable_257/Assign"
# input: "^Variable_258/Assign"
# input: "^Variable_259/Assign"
# input: "^Variable_260/Assign"
# input: "^Variable_261/Assign"
# input: "^Variable_262/Assign"
# input: "^Variable_263/Assign"
# input: "^Variable_264/Assign"
# input: "^Variable_265/Assign"
# input: "^Variable_266/Assign"
# input: "^Variable_267/Assign"
# input: "^Variable_268/Assign"
# input: "^Variable_269/Assign"
# input: "^Variable_270/Assign"
# input: "^Variable_271/Assign"
# input: "^Variable_272/Assign"
# input: "^Variable_273/Assign"
# input: "^Variable_274/Assign"
# input: "^Variable_275/Assign"
# input: "^Variable_276/Assign"
# input: "^Variable_277/Assign"
# input: "^Variable_278/Assign"
# input: "^Variable_279/Assign"
# input: "^Variable_280/Assign"
# input: "^Variable_281/Assign"
# input: "^Variable_282/Assign"
# input: "^Variable_283/Assign"
# input: "^Variable_284/Assign"
# input: "^Variable_285/Assign"
# input: "^Variable_286/Assign"
# input: "^Variable_287/Assign"
# input: "^Variable_288/Assign"
# input: "^Variable_289/Assign"
# input: "^Variable_290/Assign"
# input: "^Variable_291/Assign"
# input: "^Variable_292/Assign"
# input: "^Variable_293/Assign"
# input: "^Variable_294/Assign"
# input: "^Variable_295/Assign"
# input: "^Variable_296/Assign"
# input: "^Variable_297/Assign"
# input: "^Variable_298/Assign"
# input: "^Variable_299/Assign"
# input: "^Variable_300/Assign"
# input: "^Variable_301/Assign"
# input: "^Variable_302/Assign"
# input: "^Variable_303/Assign"
# input: "^Variable_304/Assign"
# input: "^Variable_305/Assign"
# input: "^Variable_306/Assign"
# input: "^Variable_307/Assign"
# input: "^Variable_308/Assign"
# input: "^Variable_309/Assign"
# input: "^Variable_310/Assign"
# input: "^Variable_311/Assign"
# input: "^Variable_312/Assign"
# input: "^Variable_313/Assign"
# input: "^Variable_314/Assign"
# input: "^Variable_315/Assign"
# input: "^Variable_316/Assign"
# input: "^Variable_317/Assign"
# input: "^Variable_318/Assign"
# input: "^Variable_319/Assign"
# input: "^Variable_320/Assign"
# input: "^Variable_321/Assign"
# input: "^Variable_322/Assign"
# input: "^Variable_323/Assign"
# input: "^Variable_324/Assign"
# input: "^Variable_325/Assign"
# input: "^Variable_326/Assign"
# input: "^Variable_327/Assign"
# input: "^Variable_328/Assign"
# input: "^Variable_329/Assign"
# input: "^Variable_330/Assign"
# input: "^Variable_331/Assign"
# input: "^Variable_332/Assign"
# input: "^Variable_333/Assign"
# input: "^Variable_334/Assign"
# input: "^Variable_335/Assign"
# input: "^Variable_336/Assign"
# input: "^Variable_337/Assign"
# input: "^Variable_338/Assign"
# input: "^Variable_339/Assign"
# input: "^Variable_340/Assign"
# input: "^Variable_341/Assign"
# input: "^Variable_342/Assign"
# input: "^Variable_343/Assign"
# input: "^Variable_344/Assign"
# input: "^Variable_345/Assign"
# input: "^Variable_346/Assign"
# input: "^Variable_347/Assign"
# input: "^Variable_348/Assign"
# input: "^Variable_349/Assign"
# input: "^Variable_350/Assign"
# input: "^Variable_351/Assign"
# input: "^Variable_352/Assign"
# input: "^Variable_353/Assign"
# input: "^Variable_354/Assign"
# input: "^Variable_355/Assign"
# input: "^Variable_356/Assign"
# input: "^Variable_357/Assign"
# input: "^Variable_358/Assign"
# input: "^Variable_359/Assign"
# input: "^Variable_360/Assign"
# input: "^Variable_361/Assign"
# input: "^Variable_362/Assign"
# input: "^Variable_363/Assign"
# input: "^Variable_364/Assign"
# input: "^Variable_365/Assign"
# input: "^Variable_366/Assign"
# input: "^Variable_367/Assign"
# input: "^Variable_368/Assign"
# input: "^Variable_369/Assign"
# input: "^Variable_370/Assign"
# input: "^Variable_371/Assign"
# input: "^Variable_372/Assign"
# input: "^Variable_373/Assign"
# input: "^Variable_374/Assign"
# input: "^Variable_375/Assign"
# input: "^Variable_376/Assign"
# input: "^Variable_377/Assign"
# input: "^Variable_378/Assign"
# input: "^Variable_379/Assign"
# input: "^Variable_380/Assign"
# input: "^Variable_381/Assign"
# input: "^Variable_382/Assign"
# input: "^Variable_383/Assign"
# input: "^Variable_384/Assign"
# input: "^Variable_385/Assign"
# input: "^Variable_386/Assign"
# input: "^Variable_387/Assign"
# input: "^Variable_388/Assign"
# input: "^Variable_389/Assign"
# input: "^Variable_390/Assign"
# input: "^Variable_391/Assign"
# input: "^Variable_392/Assign"
# input: "^Variable_393/Assign"
# input: "^Variable_394/Assign"
# input: "^Variable_395/Assign"
# input: "^Variable_396/Assign"
# input: "^Variable_397/Assign"
# input: "^Variable_398/Assign"
# input: "^Variable_399/Assign"
# input: "^Variable_400/Assign"
# input: "^Variable_401/Assign"
# input: "^Variable_402/Assign"
# input: "^Variable_403/Assign"
# input: "^Variable_404/Assign"
# input: "^Variable_405/Assign"
# input: "^Variable_406/Assign"
# input: "^Variable_407/Assign"
# input: "^Variable_408/Assign"
# input: "^Variable_409/Assign"
# input: "^Variable_410/Assign"
# input: "^Variable_411/Assign"
# input: "^Variable_412/Assign"
# input: "^Variable_413/Assign"
# input: "^Variable_414/Assign"
# input: "^Variable_415/Assign"
# input: "^Variable_416/Assign"
# input: "^Variable_417/Assign"
# input: "^Variable_418/Assign"
# input: "^Variable_419/Assign"
# input: "^Variable_420/Assign"
# input: "^Variable_421/Assign"
# input: "^Variable_422/Assign"
# input: "^Variable_423/Assign"
# input: "^Variable_424/Assign"
# input: "^Variable_425/Assign"
# input: "^Variable_426/Assign"
# input: "^Variable_427/Assign"
#  is not an element of this graph.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-fbe899e762d0> in <module>()
# ----> 1 model.fit(X_train, Y_train, epochs = 5, batch_size = 32)
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#    1483                               val_f=val_f, val_ins=val_ins, shuffle=shuffle,
#    1484                               callback_metrics=callback_metrics,
# -> 1485                               initial_epoch=initial_epoch)
#    1486
#    1487     def evaluate(self, x, y, batch_size=32, verbose=1, sample_weight=None):
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch)
#    1138                 batch_logs['size'] = len(batch_ids)
#    1139                 callbacks.on_batch_begin(batch_index, batch_logs)
# -> 1140                 outs = f(ins_batch)
#    1141                 if not isinstance(outs, list):
#    1142                     outs = [outs]
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2071                 value = (indices, sparse_coo.data, sparse_coo.shape)
#    2072             feed_dict[tensor] = value
# -> 2073         session = get_session()
#    2074         updated = session.run(self.outputs + [self.updates_op],
#    2075                               feed_dict=feed_dict)
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in get_session()
#     151         session = _SESSION
#     152     if not _MANUAL_VAR_INIT:
# --> 153         _initialize_variables()
#     154     return session
#     155
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in _initialize_variables()
#     304     if uninitialized_variables:
#     305         sess = get_session()
# --> 306         sess.run(tf.variables_initializer(uninitialized_variables))
#     307
#     308
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     954     try:
#     955       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 956                          run_metadata_ptr)
#     957       if run_metadata:
#     958         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1163     # Create a fetch handler to take care of the structure of fetches.
#    1164     fetch_handler = _FetchHandler(
# -> 1165         self._graph, fetches, feed_dict_tensor, feed_handles=feed_handles)
#    1166
#    1167     # Run request and get response.
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/client/session.py in __init__(self, graph, fetches, feeds, feed_handles)
#     472     """
#     473     with graph.as_default():
# --> 474       self._fetch_mapper = _FetchMapper.for_fetch(fetches)
#     475     self._fetches = []
#     476     self._targets = []
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/client/session.py in for_fetch(fetch)
#     274         if isinstance(fetch, tensor_type):
#     275           fetches, contraction_fn = fetch_fn(fetch)
# --> 276           return _ElementFetchMapper(fetches, contraction_fn)
#     277     # Did not find anything.
#     278     raise TypeError('Fetch argument %r has invalid type %r' %
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/client/session.py in __init__(self, fetches, contraction_fn)
#     310       except ValueError as e:
#     311         raise ValueError('Fetch argument %r cannot be interpreted as a '
# --> 312                          'Tensor. (%s)' % (fetch, str(e)))
#     313       except KeyError as e:
#     314         raise ValueError('Fetch argument %r cannot be interpreted as a '
#
# ValueError: Fetch argument <tf.Operation 'init_1' type=NoOp> cannot be interpreted as a Tensor. (Operation name: "init_1"
# op: "NoOp"
# input: "^res1a_branch2a/kernel/Assign"
# input: "^res1a_branch2a/bias/Assign"
# input: "^bn1a_branch2a/gamma/Assign"
# input: "^bn1a_branch2a/beta/Assign"
# input: "^bn1a_branch2a/moving_mean/Assign"
# input: "^bn1a_branch2a/moving_variance/Assign"
# input: "^res1a_branch2b/kernel/Assign"
# input: "^res1a_branch2b/bias/Assign"
# input: "^bn1a_branch2b/gamma/Assign"
# input: "^bn1a_branch2b/beta/Assign"
# input: "^bn1a_branch2b/moving_mean/Assign"
# input: "^bn1a_branch2b/moving_variance/Assign"
# input: "^res1a_branch2c/kernel/Assign"
# input: "^res1a_branch2c/bias/Assign"
# input: "^bn1a_branch2c/gamma/Assign"
# input: "^bn1a_branch2c/beta/Assign"
# input: "^bn1a_branch2c/moving_mean/Assign"
# input: "^bn1a_branch2c/moving_variance/Assign"
# input: "^res1a_branch1/kernel/Assign"
# input: "^res1a_branch1/bias/Assign"
# input: "^bn1a_branch1/gamma/Assign"
# input: "^bn1a_branch1/beta/Assign"
# input: "^bn1a_branch1/moving_mean/Assign"
# input: "^bn1a_branch1/moving_variance/Assign"
# input: "^conv1/kernel/Assign"
# input: "^conv1/bias/Assign"
# input: "^bn_conv1/gamma/Assign"
# input: "^bn_conv1/beta/Assign"
# input: "^bn_conv1/moving_mean/Assign"
# input: "^bn_conv1/moving_variance/Assign"
# input: "^res2a_branch2a/kernel/Assign"
# input: "^res2a_branch2a/bias/Assign"
# input: "^bn2a_branch2a/gamma/Assign"
# input: "^bn2a_branch2a/beta/Assign"
# input: "^bn2a_branch2a/moving_mean/Assign"
# input: "^bn2a_branch2a/moving_variance/Assign"
# input: "^res2a_branch2b/kernel/Assign"
# input: "^res2a_branch2b/bias/Assign"
# input: "^bn2a_branch2b/gamma/Assign"
# input: "^bn2a_branch2b/beta/Assign"
# input: "^bn2a_branch2b/moving_mean/Assign"
# input: "^bn2a_branch2b/moving_variance/Assign"
# input: "^res2a_branch2c/kernel/Assign"
# input: "^res2a_branch2c/bias/Assign"
# input: "^bn2a_branch2c/gamma/Assign"
# input: "^bn2a_branch2c/beta/Assign"
# input: "^bn2a_branch2c/moving_mean/Assign"
# input: "^bn2a_branch2c/moving_variance/Assign"
# input: "^res2a_branch1/kernel/Assign"
# input: "^res2a_branch1/bias/Assign"
# input: "^bn2a_branch1/gamma/Assign"
# input: "^bn2a_branch1/beta/Assign"
# input: "^bn2a_branch1/moving_mean/Assign"
# input: "^bn2a_branch1/moving_variance/Assign"
# input: "^res2b_branch2a/kernel/Assign"
# input: "^res2b_branch2a/bias/Assign"
# input: "^bn2b_branch2a/gamma/Assign"
# input: "^bn2b_branch2a/beta/Assign"
# input: "^bn2b_branch2a/moving_mean/Assign"
# input: "^bn2b_branch2a/moving_variance/Assign"
# input: "^res2b_branch2b/kernel/Assign"
# input: "^res2b_branch2b/bias/Assign"
# input: "^bn2b_branch2b/gamma/Assign"
# input: "^bn2b_branch2b/beta/Assign"
# input: "^bn2b_branch2b/moving_mean/Assign"
# input: "^bn2b_branch2b/moving_variance/Assign"
# input: "^res2b_branch2c/kernel/Assign"
# input: "^res2b_branch2c/bias/Assign"
# input: "^bn2b_branch2c/gamma/Assign"
# input: "^bn2b_branch2c/beta/Assign"
# input: "^bn2b_branch2c/moving_mean/Assign"
# input: "^bn2b_branch2c/moving_variance/Assign"
# input: "^res2c_branch2a/kernel/Assign"
# input: "^res2c_branch2a/bias/Assign"
# input: "^bn2c_branch2a/gamma/Assign"
# input: "^bn2c_branch2a/beta/Assign"
# input: "^bn2c_branch2a/moving_mean/Assign"
# input: "^bn2c_branch2a/moving_variance/Assign"
# input: "^res2c_branch2b/kernel/Assign"
# input: "^res2c_branch2b/bias/Assign"
# input: "^bn2c_branch2b/gamma/Assign"
# input: "^bn2c_branch2b/beta/Assign"
# input: "^bn2c_branch2b/moving_mean/Assign"
# input: "^bn2c_branch2b/moving_variance/Assign"
# input: "^res2c_branch2c/kernel/Assign"
# input: "^res2c_branch2c/bias/Assign"
# input: "^bn2c_branch2c/gamma/Assign"
# input: "^bn2c_branch2c/beta/Assign"
# input: "^bn2c_branch2c/moving_mean/Assign"
# input: "^bn2c_branch2c/moving_variance/Assign"
# input: "^res3a_branch2a/kernel/Assign"
# input: "^res3a_branch2a/bias/Assign"
# input: "^bn3a_branch2a/gamma/Assign"
# input: "^bn3a_branch2a/beta/Assign"
# input: "^bn3a_branch2a/moving_mean/Assign"
# input: "^bn3a_branch2a/moving_variance/Assign"
# input: "^res3a_branch2b/kernel/Assign"
# input: "^res3a_branch2b/bias/Assign"
# input: "^bn3a_branch2b/gamma/Assign"
# input: "^bn3a_branch2b/beta/Assign"
# input: "^bn3a_branch2b/moving_mean/Assign"
# input: "^bn3a_branch2b/moving_variance/Assign"
# input: "^res3a_branch2c/kernel/Assign"
# input: "^res3a_branch2c/bias/Assign"
# input: "^bn3a_branch2c/gamma/Assign"
# input: "^bn3a_branch2c/beta/Assign"
# input: "^bn3a_branch2c/moving_mean/Assign"
# input: "^bn3a_branch2c/moving_variance/Assign"
# input: "^res3a_branch1/kernel/Assign"
# input: "^res3a_branch1/bias/Assign"
# input: "^bn3a_branch1/gamma/Assign"
# input: "^bn3a_branch1/beta/Assign"
# input: "^bn3a_branch1/moving_mean/Assign"
# input: "^bn3a_branch1/moving_variance/Assign"
# input: "^res3b_branch2a/kernel/Assign"
# input: "^res3b_branch2a/bias/Assign"
# input: "^bn3b_branch2a/gamma/Assign"
# input: "^bn3b_branch2a/beta/Assign"
# input: "^bn3b_branch2a/moving_mean/Assign"
# input: "^bn3b_branch2a/moving_variance/Assign"
# input: "^res3b_branch2b/kernel/Assign"
# input: "^res3b_branch2b/bias/Assign"
# input: "^bn3b_branch2b/gamma/Assign"
# input: "^bn3b_branch2b/beta/Assign"
# input: "^bn3b_branch2b/moving_mean/Assign"
# input: "^bn3b_branch2b/moving_variance/Assign"
# input: "^res3b_branch2c/kernel/Assign"
# input: "^res3b_branch2c/bias/Assign"
# input: "^bn3b_branch2c/gamma/Assign"
# input: "^bn3b_branch2c/beta/Assign"
# input: "^bn3b_branch2c/moving_mean/Assign"
# input: "^bn3b_branch2c/moving_variance/Assign"
# input: "^res3c_branch2a/kernel/Assign"
# input: "^res3c_branch2a/bias/Assign"
# input: "^bn3c_branch2a/gamma/Assign"
# input: "^bn3c_branch2a/beta/Assign"
# input: "^bn3c_branch2a/moving_mean/Assign"
# input: "^bn3c_branch2a/moving_variance/Assign"
# input: "^res3c_branch2b/kernel/Assign"
# input: "^res3c_branch2b/bias/Assign"
# input: "^bn3c_branch2b/gamma/Assign"
# input: "^bn3c_branch2b/beta/Assign"
# input: "^bn3c_branch2b/moving_mean/Assign"
# input: "^bn3c_branch2b/moving_variance/Assign"
# input: "^res3c_branch2c/kernel/Assign"
# input: "^res3c_branch2c/bias/Assign"
# input: "^bn3c_branch2c/gamma/Assign"
# input: "^bn3c_branch2c/beta/Assign"
# input: "^bn3c_branch2c/moving_mean/Assign"
# input: "^bn3c_branch2c/moving_variance/Assign"
# input: "^res3d_branch2a/kernel/Assign"
# input: "^res3d_branch2a/bias/Assign"
# input: "^bn3d_branch2a/gamma/Assign"
# input: "^bn3d_branch2a/beta/Assign"
# input: "^bn3d_branch2a/moving_mean/Assign"
# input: "^bn3d_branch2a/moving_variance/Assign"
# input: "^res3d_branch2b/kernel/Assign"
# input: "^res3d_branch2b/bias/Assign"
# input: "^bn3d_branch2b/gamma/Assign"
# input: "^bn3d_branch2b/beta/Assign"
# input: "^bn3d_branch2b/moving_mean/Assign"
# input: "^bn3d_branch2b/moving_variance/Assign"
# input: "^res3d_branch2c/kernel/Assign"
# input: "^res3d_branch2c/bias/Assign"
# input: "^bn3d_branch2c/gamma/Assign"
# input: "^bn3d_branch2c/beta/Assign"
# input: "^bn3d_branch2c/moving_mean/Assign"
# input: "^bn3d_branch2c/moving_variance/Assign"
# input: "^res4a_branch2a/kernel/Assign"
# input: "^res4a_branch2a/bias/Assign"
# input: "^bn4a_branch2a/gamma/Assign"
# input: "^bn4a_branch2a/beta/Assign"
# input: "^bn4a_branch2a/moving_mean/Assign"
# input: "^bn4a_branch2a/moving_variance/Assign"
# input: "^res4a_branch2b/kernel/Assign"
# input: "^res4a_branch2b/bias/Assign"
# input: "^bn4a_branch2b/gamma/Assign"
# input: "^bn4a_branch2b/beta/Assign"
# input: "^bn4a_branch2b/moving_mean/Assign"
# input: "^bn4a_branch2b/moving_variance/Assign"
# input: "^res4a_branch2c/kernel/Assign"
# input: "^res4a_branch2c/bias/Assign"
# input: "^bn4a_branch2c/gamma/Assign"
# input: "^bn4a_branch2c/beta/Assign"
# input: "^bn4a_branch2c/moving_mean/Assign"
# input: "^bn4a_branch2c/moving_variance/Assign"
# input: "^res4a_branch1/kernel/Assign"
# input: "^res4a_branch1/bias/Assign"
# input: "^bn4a_branch1/gamma/Assign"
# input: "^bn4a_branch1/beta/Assign"
# input: "^bn4a_branch1/moving_mean/Assign"
# input: "^bn4a_branch1/moving_variance/Assign"
# input: "^res4b_branch2a/kernel/Assign"
# input: "^res4b_branch2a/bias/Assign"
# input: "^bn4b_branch2a/gamma/Assign"
# input: "^bn4b_branch2a/beta/Assign"
# input: "^bn4b_branch2a/moving_mean/Assign"
# input: "^bn4b_branch2a/moving_variance/Assign"
# input: "^res4b_branch2b/kernel/Assign"
# input: "^res4b_branch2b/bias/Assign"
# input: "^bn4b_branch2b/gamma/Assign"
# input: "^bn4b_branch2b/beta/Assign"
# input: "^bn4b_branch2b/moving_mean/Assign"
# input: "^bn4b_branch2b/moving_variance/Assign"
# input: "^res4b_branch2c/kernel/Assign"
# input: "^res4b_branch2c/bias/Assign"
# input: "^bn4b_branch2c/gamma/Assign"
# input: "^bn4b_branch2c/beta/Assign"
# input: "^bn4b_branch2c/moving_mean/Assign"
# input: "^bn4b_branch2c/moving_variance/Assign"
# input: "^res4c_branch2a/kernel/Assign"
# input: "^res4c_branch2a/bias/Assign"
# input: "^bn4c_branch2a/gamma/Assign"
# input: "^bn4c_branch2a/beta/Assign"
# input: "^bn4c_branch2a/moving_mean/Assign"
# input: "^bn4c_branch2a/moving_variance/Assign"
# input: "^res4c_branch2b/kernel/Assign"
# input: "^res4c_branch2b/bias/Assign"
# input: "^bn4c_branch2b/gamma/Assign"
# input: "^bn4c_branch2b/beta/Assign"
# input: "^bn4c_branch2b/moving_mean/Assign"
# input: "^bn4c_branch2b/moving_variance/Assign"
# input: "^res4c_branch2c/kernel/Assign"
# input: "^res4c_branch2c/bias/Assign"
# input: "^bn4c_branch2c/gamma/Assign"
# input: "^bn4c_branch2c/beta/Assign"
# input: "^bn4c_branch2c/moving_mean/Assign"
# input: "^bn4c_branch2c/moving_variance/Assign"
# input: "^res4d_branch2a/kernel/Assign"
# input: "^res4d_branch2a/bias/Assign"
# input: "^bn4d_branch2a/gamma/Assign"
# input: "^bn4d_branch2a/beta/Assign"
# input: "^bn4d_branch2a/moving_mean/Assign"
# input: "^bn4d_branch2a/moving_variance/Assign"
# input: "^res4d_branch2b/kernel/Assign"
# input: "^res4d_branch2b/bias/Assign"
# input: "^bn4d_branch2b/gamma/Assign"
# input: "^bn4d_branch2b/beta/Assign"
# input: "^bn4d_branch2b/moving_mean/Assign"
# input: "^bn4d_branch2b/moving_variance/Assign"
# input: "^res4d_branch2c/kernel/Assign"
# input: "^res4d_branch2c/bias/Assign"
# input: "^bn4d_branch2c/gamma/Assign"
# input: "^bn4d_branch2c/beta/Assign"
# input: "^bn4d_branch2c/moving_mean/Assign"
# input: "^bn4d_branch2c/moving_variance/Assign"
# input: "^res4e_branch2a/kernel/Assign"
# input: "^res4e_branch2a/bias/Assign"
# input: "^bn4e_branch2a/gamma/Assign"
# input: "^bn4e_branch2a/beta/Assign"
# input: "^bn4e_branch2a/moving_mean/Assign"
# input: "^bn4e_branch2a/moving_variance/Assign"
# input: "^res4e_branch2b/kernel/Assign"
# input: "^res4e_branch2b/bias/Assign"
# input: "^bn4e_branch2b/gamma/Assign"
# input: "^bn4e_branch2b/beta/Assign"
# input: "^bn4e_branch2b/moving_mean/Assign"
# input: "^bn4e_branch2b/moving_variance/Assign"
# input: "^res4e_branch2c/kernel/Assign"
# input: "^res4e_branch2c/bias/Assign"
# input: "^bn4e_branch2c/gamma/Assign"
# input: "^bn4e_branch2c/beta/Assign"
# input: "^bn4e_branch2c/moving_mean/Assign"
# input: "^bn4e_branch2c/moving_variance/Assign"
# input: "^res4f_branch2a/kernel/Assign"
# input: "^res4f_branch2a/bias/Assign"
# input: "^bn4f_branch2a/gamma/Assign"
# input: "^bn4f_branch2a/beta/Assign"
# input: "^bn4f_branch2a/moving_mean/Assign"
# input: "^bn4f_branch2a/moving_variance/Assign"
# input: "^res4f_branch2b/kernel/Assign"
# input: "^res4f_branch2b/bias/Assign"
# input: "^bn4f_branch2b/gamma/Assign"
# input: "^bn4f_branch2b/beta/Assign"
# input: "^bn4f_branch2b/moving_mean/Assign"
# input: "^bn4f_branch2b/moving_variance/Assign"
# input: "^res4f_branch2c/kernel/Assign"
# input: "^res4f_branch2c/bias/Assign"
# input: "^bn4f_branch2c/gamma/Assign"
# input: "^bn4f_branch2c/beta/Assign"
# input: "^bn4f_branch2c/moving_mean/Assign"
# input: "^bn4f_branch2c/moving_variance/Assign"
# input: "^res5a_branch2a/kernel/Assign"
# input: "^res5a_branch2a/bias/Assign"
# input: "^bn5a_branch2a/gamma/Assign"
# input: "^bn5a_branch2a/beta/Assign"
# input: "^bn5a_branch2a/moving_mean/Assign"
# input: "^bn5a_branch2a/moving_variance/Assign"
# input: "^res5a_branch2b/kernel/Assign"
# input: "^res5a_branch2b/bias/Assign"
# input: "^bn5a_branch2b/gamma/Assign"
# input: "^bn5a_branch2b/beta/Assign"
# input: "^bn5a_branch2b/moving_mean/Assign"
# input: "^bn5a_branch2b/moving_variance/Assign"
# input: "^res5a_branch2c/kernel/Assign"
# input: "^res5a_branch2c/bias/Assign"
# input: "^bn5a_branch2c/gamma/Assign"
# input: "^bn5a_branch2c/beta/Assign"
# input: "^bn5a_branch2c/moving_mean/Assign"
# input: "^bn5a_branch2c/moving_variance/Assign"
# input: "^res5a_branch1/kernel/Assign"
# input: "^res5a_branch1/bias/Assign"
# input: "^bn5a_branch1/gamma/Assign"
# input: "^bn5a_branch1/beta/Assign"
# input: "^bn5a_branch1/moving_mean/Assign"
# input: "^bn5a_branch1/moving_variance/Assign"
# input: "^res5b_branch2a/kernel/Assign"
# input: "^res5b_branch2a/bias/Assign"
# input: "^bn5b_branch2a/gamma/Assign"
# input: "^bn5b_branch2a/beta/Assign"
# input: "^bn5b_branch2a/moving_mean/Assign"
# input: "^bn5b_branch2a/moving_variance/Assign"
# input: "^res5b_branch2b/kernel/Assign"
# input: "^res5b_branch2b/bias/Assign"
# input: "^bn5b_branch2b/gamma/Assign"
# input: "^bn5b_branch2b/beta/Assign"
# input: "^bn5b_branch2b/moving_mean/Assign"
# input: "^bn5b_branch2b/moving_variance/Assign"
# input: "^res5b_branch2c/kernel/Assign"
# input: "^res5b_branch2c/bias/Assign"
# input: "^bn5b_branch2c/gamma/Assign"
# input: "^bn5b_branch2c/beta/Assign"
# input: "^bn5b_branch2c/moving_mean/Assign"
# input: "^bn5b_branch2c/moving_variance/Assign"
# input: "^res5c_branch2a/kernel/Assign"
# input: "^res5c_branch2a/bias/Assign"
# input: "^bn5c_branch2a/gamma/Assign"
# input: "^bn5c_branch2a/beta/Assign"
# input: "^bn5c_branch2a/moving_mean/Assign"
# input: "^bn5c_branch2a/moving_variance/Assign"
# input: "^res5c_branch2b/kernel/Assign"
# input: "^res5c_branch2b/bias/Assign"
# input: "^bn5c_branch2b/gamma/Assign"
# input: "^bn5c_branch2b/beta/Assign"
# input: "^bn5c_branch2b/moving_mean/Assign"
# input: "^bn5c_branch2b/moving_variance/Assign"
# input: "^res5c_branch2c/kernel/Assign"
# input: "^res5c_branch2c/bias/Assign"
# input: "^bn5c_branch2c/gamma/Assign"
# input: "^bn5c_branch2c/beta/Assign"
# input: "^bn5c_branch2c/moving_mean/Assign"
# input: "^bn5c_branch2c/moving_variance/Assign"
# input: "^fc6/kernel/Assign"
# input: "^fc6/bias/Assign"
# input: "^iterations/Assign"
# input: "^lr/Assign"
# input: "^beta_1/Assign"
# input: "^beta_2/Assign"
# input: "^decay/Assign"
# input: "^Variable/Assign"
# input: "^Variable_1/Assign"
# input: "^Variable_2/Assign"
# input: "^Variable_3/Assign"
# input: "^Variable_4/Assign"
# input: "^Variable_5/Assign"
# input: "^Variable_6/Assign"
# input: "^Variable_7/Assign"
# input: "^Variable_8/Assign"
# input: "^Variable_9/Assign"
# input: "^Variable_10/Assign"
# input: "^Variable_11/Assign"
# input: "^Variable_12/Assign"
# input: "^Variable_13/Assign"
# input: "^Variable_14/Assign"
# input: "^Variable_15/Assign"
# input: "^Variable_16/Assign"
# input: "^Variable_17/Assign"
# input: "^Variable_18/Assign"
# input: "^Variable_19/Assign"
# input: "^Variable_20/Assign"
# input: "^Variable_21/Assign"
# input: "^Variable_22/Assign"
# input: "^Variable_23/Assign"
# input: "^Variable_24/Assign"
# input: "^Variable_25/Assign"
# input: "^Variable_26/Assign"
# input: "^Variable_27/Assign"
# input: "^Variable_28/Assign"
# input: "^Variable_29/Assign"
# input: "^Variable_30/Assign"
# input: "^Variable_31/Assign"
# input: "^Variable_32/Assign"
# input: "^Variable_33/Assign"
# input: "^Variable_34/Assign"
# input: "^Variable_35/Assign"
# input: "^Variable_36/Assign"
# input: "^Variable_37/Assign"
# input: "^Variable_38/Assign"
# input: "^Variable_39/Assign"
# input: "^Variable_40/Assign"
# input: "^Variable_41/Assign"
# input: "^Variable_42/Assign"
# input: "^Variable_43/Assign"
# input: "^Variable_44/Assign"
# input: "^Variable_45/Assign"
# input: "^Variable_46/Assign"
# input: "^Variable_47/Assign"
# input: "^Variable_48/Assign"
# input: "^Variable_49/Assign"
# input: "^Variable_50/Assign"
# input: "^Variable_51/Assign"
# input: "^Variable_52/Assign"
# input: "^Variable_53/Assign"
# input: "^Variable_54/Assign"
# input: "^Variable_55/Assign"
# input: "^Variable_56/Assign"
# input: "^Variable_57/Assign"
# input: "^Variable_58/Assign"
# input: "^Variable_59/Assign"
# input: "^Variable_60/Assign"
# input: "^Variable_61/Assign"
# input: "^Variable_62/Assign"
# input: "^Variable_63/Assign"
# input: "^Variable_64/Assign"
# input: "^Variable_65/Assign"
# input: "^Variable_66/Assign"
# input: "^Variable_67/Assign"
# input: "^Variable_68/Assign"
# input: "^Variable_69/Assign"
# input: "^Variable_70/Assign"
# input: "^Variable_71/Assign"
# input: "^Variable_72/Assign"
# input: "^Variable_73/Assign"
# input: "^Variable_74/Assign"
# input: "^Variable_75/Assign"
# input: "^Variable_76/Assign"
# input: "^Variable_77/Assign"
# input: "^Variable_78/Assign"
# input: "^Variable_79/Assign"
# input: "^Variable_80/Assign"
# input: "^Variable_81/Assign"
# input: "^Variable_82/Assign"
# input: "^Variable_83/Assign"
# input: "^Variable_84/Assign"
# input: "^Variable_85/Assign"
# input: "^Variable_86/Assign"
# input: "^Variable_87/Assign"
# input: "^Variable_88/Assign"
# input: "^Variable_89/Assign"
# input: "^Variable_90/Assign"
# input: "^Variable_91/Assign"
# input: "^Variable_92/Assign"
# input: "^Variable_93/Assign"
# input: "^Variable_94/Assign"
# input: "^Variable_95/Assign"
# input: "^Variable_96/Assign"
# input: "^Variable_97/Assign"
# input: "^Variable_98/Assign"
# input: "^Variable_99/Assign"
# input: "^Variable_100/Assign"
# input: "^Variable_101/Assign"
# input: "^Variable_102/Assign"
# input: "^Variable_103/Assign"
# input: "^Variable_104/Assign"
# input: "^Variable_105/Assign"
# input: "^Variable_106/Assign"
# input: "^Variable_107/Assign"
# input: "^Variable_108/Assign"
# input: "^Variable_109/Assign"
# input: "^Variable_110/Assign"
# input: "^Variable_111/Assign"
# input: "^Variable_112/Assign"
# input: "^Variable_113/Assign"
# input: "^Variable_114/Assign"
# input: "^Variable_115/Assign"
# input: "^Variable_116/Assign"
# input: "^Variable_117/Assign"
# input: "^Variable_118/Assign"
# input: "^Variable_119/Assign"
# input: "^Variable_120/Assign"
# input: "^Variable_121/Assign"
# input: "^Variable_122/Assign"
# input: "^Variable_123/Assign"
# input: "^Variable_124/Assign"
# input: "^Variable_125/Assign"
# input: "^Variable_126/Assign"
# input: "^Variable_127/Assign"
# input: "^Variable_128/Assign"
# input: "^Variable_129/Assign"
# input: "^Variable_130/Assign"
# input: "^Variable_131/Assign"
# input: "^Variable_132/Assign"
# input: "^Variable_133/Assign"
# input: "^Variable_134/Assign"
# input: "^Variable_135/Assign"
# input: "^Variable_136/Assign"
# input: "^Variable_137/Assign"
# input: "^Variable_138/Assign"
# input: "^Variable_139/Assign"
# input: "^Variable_140/Assign"
# input: "^Variable_141/Assign"
# input: "^Variable_142/Assign"
# input: "^Variable_143/Assign"
# input: "^Variable_144/Assign"
# input: "^Variable_145/Assign"
# input: "^Variable_146/Assign"
# input: "^Variable_147/Assign"
# input: "^Variable_148/Assign"
# input: "^Variable_149/Assign"
# input: "^Variable_150/Assign"
# input: "^Variable_151/Assign"
# input: "^Variable_152/Assign"
# input: "^Variable_153/Assign"
# input: "^Variable_154/Assign"
# input: "^Variable_155/Assign"
# input: "^Variable_156/Assign"
# input: "^Variable_157/Assign"
# input: "^Variable_158/Assign"
# input: "^Variable_159/Assign"
# input: "^Variable_160/Assign"
# input: "^Variable_161/Assign"
# input: "^Variable_162/Assign"
# input: "^Variable_163/Assign"
# input: "^Variable_164/Assign"
# input: "^Variable_165/Assign"
# input: "^Variable_166/Assign"
# input: "^Variable_167/Assign"
# input: "^Variable_168/Assign"
# input: "^Variable_169/Assign"
# input: "^Variable_170/Assign"
# input: "^Variable_171/Assign"
# input: "^Variable_172/Assign"
# input: "^Variable_173/Assign"
# input: "^Variable_174/Assign"
# input: "^Variable_175/Assign"
# input: "^Variable_176/Assign"
# input: "^Variable_177/Assign"
# input: "^Variable_178/Assign"
# input: "^Variable_179/Assign"
# input: "^Variable_180/Assign"
# input: "^Variable_181/Assign"
# input: "^Variable_182/Assign"
# input: "^Variable_183/Assign"
# input: "^Variable_184/Assign"
# input: "^Variable_185/Assign"
# input: "^Variable_186/Assign"
# input: "^Variable_187/Assign"
# input: "^Variable_188/Assign"
# input: "^Variable_189/Assign"
# input: "^Variable_190/Assign"
# input: "^Variable_191/Assign"
# input: "^Variable_192/Assign"
# input: "^Variable_193/Assign"
# input: "^Variable_194/Assign"
# input: "^Variable_195/Assign"
# input: "^Variable_196/Assign"
# input: "^Variable_197/Assign"
# input: "^Variable_198/Assign"
# input: "^Variable_199/Assign"
# input: "^Variable_200/Assign"
# input: "^Variable_201/Assign"
# input: "^Variable_202/Assign"
# input: "^Variable_203/Assign"
# input: "^Variable_204/Assign"
# input: "^Variable_205/Assign"
# input: "^Variable_206/Assign"
# input: "^Variable_207/Assign"
# input: "^Variable_208/Assign"
# input: "^Variable_209/Assign"
# input: "^Variable_210/Assign"
# input: "^Variable_211/Assign"
# input: "^Variable_212/Assign"
# input: "^Variable_213/Assign"
# input: "^Variable_214/Assign"
# input: "^Variable_215/Assign"
# input: "^Variable_216/Assign"
# input: "^Variable_217/Assign"
# input: "^Variable_218/Assign"
# input: "^Variable_219/Assign"
# input: "^Variable_220/Assign"
# input: "^Variable_221/Assign"
# input: "^Variable_222/Assign"
# input: "^Variable_223/Assign"
# input: "^Variable_224/Assign"
# input: "^Variable_225/Assign"
# input: "^Variable_226/Assign"
# input: "^Variable_227/Assign"
# input: "^Variable_228/Assign"
# input: "^Variable_229/Assign"
# input: "^Variable_230/Assign"
# input: "^Variable_231/Assign"
# input: "^Variable_232/Assign"
# input: "^Variable_233/Assign"
# input: "^Variable_234/Assign"
# input: "^Variable_235/Assign"
# input: "^Variable_236/Assign"
# input: "^Variable_237/Assign"
# input: "^Variable_238/Assign"
# input: "^Variable_239/Assign"
# input: "^Variable_240/Assign"
# input: "^Variable_241/Assign"
# input: "^Variable_242/Assign"
# input: "^Variable_243/Assign"
# input: "^Variable_244/Assign"
# input: "^Variable_245/Assign"
# input: "^Variable_246/Assign"
# input: "^Variable_247/Assign"
# input: "^Variable_248/Assign"
# input: "^Variable_249/Assign"
# input: "^Variable_250/Assign"
# input: "^Variable_251/Assign"
# input: "^Variable_252/Assign"
# input: "^Variable_253/Assign"
# input: "^Variable_254/Assign"
# input: "^Variable_255/Assign"
# input: "^Variable_256/Assign"
# input: "^Variable_257/Assign"
# input: "^Variable_258/Assign"
# input: "^Variable_259/Assign"
# input: "^Variable_260/Assign"
# input: "^Variable_261/Assign"
# input: "^Variable_262/Assign"
# input: "^Variable_263/Assign"
# input: "^Variable_264/Assign"
# input: "^Variable_265/Assign"
# input: "^Variable_266/Assign"
# input: "^Variable_267/Assign"
# input: "^Variable_268/Assign"
# input: "^Variable_269/Assign"
# input: "^Variable_270/Assign"
# input: "^Variable_271/Assign"
# input: "^Variable_272/Assign"
# input: "^Variable_273/Assign"
# input: "^Variable_274/Assign"
# input: "^Variable_275/Assign"
# input: "^Variable_276/Assign"
# input: "^Variable_277/Assign"
# input: "^Variable_278/Assign"
# input: "^Variable_279/Assign"
# input: "^Variable_280/Assign"
# input: "^Variable_281/Assign"
# input: "^Variable_282/Assign"
# input: "^Variable_283/Assign"
# input: "^Variable_284/Assign"
# input: "^Variable_285/Assign"
# input: "^Variable_286/Assign"
# input: "^Variable_287/Assign"
# input: "^Variable_288/Assign"
# input: "^Variable_289/Assign"
# input: "^Variable_290/Assign"
# input: "^Variable_291/Assign"
# input: "^Variable_292/Assign"
# input: "^Variable_293/Assign"
# input: "^Variable_294/Assign"
# input: "^Variable_295/Assign"
# input: "^Variable_296/Assign"
# input: "^Variable_297/Assign"
# input: "^Variable_298/Assign"
# input: "^Variable_299/Assign"
# input: "^Variable_300/Assign"
# input: "^Variable_301/Assign"
# input: "^Variable_302/Assign"
# input: "^Variable_303/Assign"
# input: "^Variable_304/Assign"
# input: "^Variable_305/Assign"
# input: "^Variable_306/Assign"
# input: "^Variable_307/Assign"
# input: "^Variable_308/Assign"
# input: "^Variable_309/Assign"
# input: "^Variable_310/Assign"
# input: "^Variable_311/Assign"
# input: "^Variable_312/Assign"
# input: "^Variable_313/Assign"
# input: "^Variable_314/Assign"
# input: "^Variable_315/Assign"
# input: "^Variable_316/Assign"
# input: "^Variable_317/Assign"
# input: "^Variable_318/Assign"
# input: "^Variable_319/Assign"
# input: "^Variable_320/Assign"
# input: "^Variable_321/Assign"
# input: "^Variable_322/Assign"
# input: "^Variable_323/Assign"
# input: "^Variable_324/Assign"
# input: "^Variable_325/Assign"
# input: "^Variable_326/Assign"
# input: "^Variable_327/Assign"
# input: "^Variable_328/Assign"
# input: "^Variable_329/Assign"
# input: "^Variable_330/Assign"
# input: "^Variable_331/Assign"
# input: "^Variable_332/Assign"
# input: "^Variable_333/Assign"
# input: "^Variable_334/Assign"
# input: "^Variable_335/Assign"
# input: "^Variable_336/Assign"
# input: "^Variable_337/Assign"
# input: "^Variable_338/Assign"
# input: "^Variable_339/Assign"
# input: "^Variable_340/Assign"
# input: "^Variable_341/Assign"
# input: "^Variable_342/Assign"
# input: "^Variable_343/Assign"
# input: "^Variable_344/Assign"
# input: "^Variable_345/Assign"
# input: "^Variable_346/Assign"
# input: "^Variable_347/Assign"
# input: "^Variable_348/Assign"
# input: "^Variable_349/Assign"
# input: "^Variable_350/Assign"
# input: "^Variable_351/Assign"
# input: "^Variable_352/Assign"
# input: "^Variable_353/Assign"
# input: "^Variable_354/Assign"
# input: "^Variable_355/Assign"
# input: "^Variable_356/Assign"
# input: "^Variable_357/Assign"
# input: "^Variable_358/Assign"
# input: "^Variable_359/Assign"
# input: "^Variable_360/Assign"
# input: "^Variable_361/Assign"
# input: "^Variable_362/Assign"
# input: "^Variable_363/Assign"
# input: "^Variable_364/Assign"
# input: "^Variable_365/Assign"
# input: "^Variable_366/Assign"
# input: "^Variable_367/Assign"
# input: "^Variable_368/Assign"
# input: "^Variable_369/Assign"
# input: "^Variable_370/Assign"
# input: "^Variable_371/Assign"
# input: "^Variable_372/Assign"
# input: "^Variable_373/Assign"
# input: "^Variable_374/Assign"
# input: "^Variable_375/Assign"
# input: "^Variable_376/Assign"
# input: "^Variable_377/Assign"
# input: "^Variable_378/Assign"
# input: "^Variable_379/Assign"
# input: "^Variable_380/Assign"
# input: "^Variable_381/Assign"
# input: "^Variable_382/Assign"
# input: "^Variable_383/Assign"
# input: "^Variable_384/Assign"
# input: "^Variable_385/Assign"
# input: "^Variable_386/Assign"
# input: "^Variable_387/Assign"
# input: "^Variable_388/Assign"
# input: "^Variable_389/Assign"
# input: "^Variable_390/Assign"
# input: "^Variable_391/Assign"
# input: "^Variable_392/Assign"
# input: "^Variable_393/Assign"
# input: "^Variable_394/Assign"
# input: "^Variable_395/Assign"
# input: "^Variable_396/Assign"
# input: "^Variable_397/Assign"
# input: "^Variable_398/Assign"
# input: "^Variable_399/Assign"
# input: "^Variable_400/Assign"
# input: "^Variable_401/Assign"
# input: "^Variable_402/Assign"
# input: "^Variable_403/Assign"
# input: "^Variable_404/Assign"
# input: "^Variable_405/Assign"
# input: "^Variable_406/Assign"
# input: "^Variable_407/Assign"
# input: "^Variable_408/Assign"
# input: "^Variable_409/Assign"
# input: "^Variable_410/Assign"
# input: "^Variable_411/Assign"
# input: "^Variable_412/Assign"
# input: "^Variable_413/Assign"
# input: "^Variable_414/Assign"
# input: "^Variable_415/Assign"
# input: "^Variable_416/Assign"
# input: "^Variable_417/Assign"
# input: "^Variable_418/Assign"
# input: "^Variable_419/Assign"
# input: "^Variable_420/Assign"
# input: "^Variable_421/Assign"
# input: "^Variable_422/Assign"
# input: "^Variable_423/Assign"
# input: "^Variable_424/Assign"
# input: "^Variable_425/Assign"
# input: "^Variable_426/Assign"
# input: "^Variable_427/Assign"
#  is not an element of this graph.)

# %%
preds = model.evaluate(X_test, Y_test)
print ("Loss = " + str(preds[0]))
print ("Test Accuracy = " + str(preds[1]))
# Out:
#  96/120 [=======================>......] - ETA: 0sLoss = 0.15218120614687602
# Test Accuracy = 0.925
